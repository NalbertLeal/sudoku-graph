# %%
import multiprocessing as mp
import numpy as np
import pandas as pd
from tqdm import tqdm, tqdm_notebook
tqdm_notebook().pandas()

# %%
class Graph():
    def __init__(self, vertices_list=[]):
        self.vertices = np.array(vertices_list)
        self.edges = np.zeros(shape=(self.vertices.size, self.vertices.size))

    def get_adjacents(self, vertice_index):
        """
          Using the self.edges return a np.array with the index of the 
        vertices that are adjacent of the "vertice_index" of the paramenter.
        """
        adjacents = []
        for index in range(0, len(self.edges)):
            if self.edges[vertice_index, index] == 1:
                adjacents.append(index)
            return np.array(adjacents)

    def greed(self):
        pass

    def ldo(self):
        pass
    def sdo(self):
        pass

# %%
sudoku_dataset = pd.read_csv('sudoku.csv')

# %%
sudoku_dataset
# Out:
#                                                   quizzes  \
# 0       0043002090050090010700600430060020871900074000...
# 1       0401000501070039605200080000000000170009068008...
# 2       6001203840084590720000060050002640300700800069...
# 3       4972000001004000050000160986203000403009000000...
# 4       0059103080094030600275001000300002010008200070...
# 5       1000050073809000006000004808200010750407600200...
# 6       0090654300070008006001080200030900025014039608...
# 7       0000006577024001003500060005000200092103005000...
# 8       5030701900000067500471906004000380009502003000...
# 9       0607209080840030017001000659000080000710600000...
# 10      0040830020510043000000967101208000060400005008...
# 11      0000602807090010008603200749000405100071903400...
# 12      0043000008902006707009000505000081400700320606...
# 13      0080701001200900540000030206040100895307800100...
# 14      0653700020000013700006408000970040280800900011...
# ...

# %%
with tqdm(total=len(list(sudoku_dataset.iterrows()))) as pbar:
    for index, row in sudoku_dataset.iterrows():
        pbar.update(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-117bb0bd6313> in <module>
# ----> 1 with tqdm(total=len(list(sudoku_dataset.iterrows()))) as pbar:
#       2     for index, row in sudoku_dataset.iterrows():
#       3         pbar.update(1)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in iterrows(self)
#     773         klass = self._constructor_sliced
#     774         for k, v in zip(self.index, self.values):
# --> 775             s = klass(v, index=columns, name=k)
#     776             yield k, s
#     777
#
# ~/.local/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     273             else:
#     274                 data = _sanitize_array(data, index, dtype, copy,
# --> 275                                        raise_cast_failure=True)
#     276
# ...

# %%
for index, row in tqdm(sudoku_dataset.iterrows()):
    pass
# Out:
# 183329it [00:16, 10759.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3439b0561341> in <module>
# ----> 1 for index, row in tqdm(sudoku_dataset.iterrows()):
#       2     pass
#
# /usr/local/lib/python3.5/dist-packages/tqdm/_tqdm.py in __iter__(self)
#     977 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     978
# --> 979             for obj in iterable:
#     980                 yield obj
#     981                 # Update and possibly print the progressbar.
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in iterrows(self)
#     773         klass = self._constructor_sliced
#     774         for k, v in zip(self.index, self.values):
# --> 775             s = klass(v, index=columns, name=k)
#     776             yield k, s
#     777
#
# ...

# %%
graph = Graph(list(str(sudoku_dataset.iat[0,0])))

# %%
graph.edges

# %%
graph.get_adjacents(1)
